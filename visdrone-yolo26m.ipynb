# %%
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 101110, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 101110 (delta 214), reused 198 (delta 186), pack-reused 100863 (from 3)
# Receiving objects: 100% (101110/101110), 53.71 MiB | 24.60 MiB/s, done.
# Resolving deltas: 100% (75986/75986), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.1 MB/s eta 0:00:0000:0100:01
#   Building editable for ultralytics (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

# Define your YAML content as a multi-line string
yaml_content = """
# Dataset paths
path: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset  # dataset root dir
train: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train/images  # train images
val: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-val/images    # val images
test: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-test-dev/images # test images

#number of classes
nc: 2

# Class names
names: ['person', 'car']
"""

# Write the YAML content to a file
with open('dataset.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !yolo train model=yolo26n.pt data=/kaggle/working/dataset.yaml epochs=50 imgsz=960 patience=35 cache=true batch=16 save=true device=0,1 name=run optimizer=SGD
# Out:
# Ultralytics 8.4.51 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run-6, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=35, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/ultralytics/runs/detect/run-6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241956  ultralytics.nn.modules.head.Detect           [2, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,580 parameters, 2,504,580 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 50757 /root/.config/Ultralytics/DDP/_temp_qrk_g8jw140004210160656.py
# Ultralytics 8.4.51 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# Overriding model.yaml nc=80 with nc=2
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.6 ms, read: 13.8±6.5 MB/s, size: 206.8 KB)
# train: Scanning /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train/labels... 6471 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 208.7it/s 31.0s<0.0s
# train: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train/images/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train/images/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train/images/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-train is not writable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (11.0GB RAM): 100% ━━━━━━━━━━━━ 6471/6471 181.8it/s 35.6s<0.1s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 26.3±8.6 MB/s, size: 150.3 KB)
# val: Scanning /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-val/labels... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 244.8it/s 2.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/fateennr/visdrone-dataset/visDrone/VisDrone_Dataset/VisDrone2019-DET-val is not writable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.8GB RAM): 100% ━━━━━━━━━━━━ 548/548 258.5it/s 2.1s0.1s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/ultralytics/runs/detect/run-6/labels.jpg...
# Image sizes 960 train, 960 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/ultralytics/runs/detect/run-6
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      9.63G      2.171       2.71   0.002616        278        960: 100% ━━━━━━━━━━━━ 405/405 2.4it/s 2:49<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s0.2s
#                    all        548      28033      0.402      0.409      0.322      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      8.49G      2.162      1.884   0.002412        196        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s0.2s
#                    all        548      28033      0.484      0.455      0.411      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      8.04G       2.13      1.715   0.002403        264        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.537      0.482      0.461      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      7.36G      2.124      1.624   0.002363        291        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.536      0.477      0.469      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      9.37G      2.085      1.543   0.002311        229        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.575      0.507       0.51      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      7.87G      2.066      1.495   0.002274        290        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.611      0.518      0.545        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.83G      2.053      1.433   0.002196        302        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.625      0.529      0.555      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      9.41G      2.055      1.414   0.002236        398        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s0.2s
#                    all        548      28033      0.612      0.541      0.557      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      13.4G      2.007       1.38   0.002235        473        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s0.2s
#                    all        548      28033      0.634      0.542      0.571      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.34G      2.016      1.363   0.002187        193        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s0.2s
#                    all        548      28033      0.662      0.548      0.587      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       6.4G      2.006      1.341   0.002193        255        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s0.2s
#                    all        548      28033      0.661      0.556      0.594      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      9.04G      2.015      1.332   0.002169        254        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.6s0.2s
#                    all        548      28033      0.677      0.555      0.604       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      9.19G      2.008      1.322   0.002157        108        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.676      0.559      0.604      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.17G      1.988      1.302   0.002158        194        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s0.2s
#                    all        548      28033      0.678      0.562      0.606       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.1G      1.988      1.289   0.002135        152        960: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s0.2s
#                    all        548      28033      0.676       0.56      0.602      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      7.39G      2.001      1.292   0.002133        135        960: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:33<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s0.2s
#                    all        548      28033      0.692      0.565      0.614      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      6.29G      1.976      1.259   0.002124        248        960: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.686      0.578      0.625      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       6.3G      1.976      1.254   0.002115        480        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.693       0.58      0.628      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      9.02G      1.958      1.244   0.002098        451        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s0.2s
#                    all        548      28033      0.693      0.581      0.627      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      8.25G      1.945      1.239   0.002088        272        960: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:33<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.5it/s 3.3s0.2s
#                    all        548      28033      0.707      0.576      0.633      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      7.19G      1.966       1.24   0.002087        290        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.697      0.575      0.629      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      7.21G      1.945      1.229   0.002091        222        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.697      0.584      0.633      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      11.6G      1.929      1.212   0.002074        217        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.704       0.59       0.64      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      7.03G      1.922      1.208    0.00206        409        960: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:32<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s0.2s
#                    all        548      28033      0.703      0.592       0.64       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      7.03G      1.922      1.193   0.002036        150        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.712      0.588      0.643      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      9.45G      1.924      1.199   0.002044        196        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.715      0.587      0.644      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.57G      1.923      1.191   0.002021        129        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s0.2s
#                    all        548      28033      0.703      0.589       0.64      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      7.96G      1.915      1.185   0.002036        278        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.719      0.597      0.651      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      8.82G      1.905      1.172   0.002007        175        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s0.2s
#                    all        548      28033      0.715      0.598      0.651      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.39G      1.899      1.168   0.002014        171        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s0.2s
#                    all        548      28033      0.719      0.599      0.654      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      9.13G      1.906      1.172   0.001995        346        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s0.2s
#                    all        548      28033      0.718      0.603      0.658      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      7.67G        1.9      1.163    0.00197        419        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.717      0.609      0.661       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      8.86G       1.89      1.158   0.001985        185        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.723      0.602       0.66      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50       9.9G      1.873      1.146   0.001975        216        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s0.2s
#                    all        548      28033      0.721      0.606      0.665      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      8.58G      1.908      1.153   0.001958        223        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.729      0.605      0.664      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.38G       1.87       1.14   0.001968        217        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.725      0.608      0.665      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.38G      1.859      1.126   0.001942        166        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.733      0.605      0.666      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      7.74G      1.873      1.129   0.001936        339        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.727      0.615       0.67      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50       6.3G       1.86      1.123   0.001941        168        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.737      0.608       0.67      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.7G      1.874      1.125   0.001921        424        960: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s0.2s
#                    all        548      28033      0.733      0.606      0.666      0.385
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      8.62G      1.802      1.104   0.002027        170        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s0.2s
#                    all        548      28033      0.727       0.61      0.665      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      9.51G      1.782      1.082   0.002013        174        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.729      0.606      0.665      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      9.68G        1.8      1.092   0.001985        108        960: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:22<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.737      0.607      0.667      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      9.37G      1.779      1.079   0.001992        255        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s0.2s
#                    all        548      28033      0.735       0.61       0.67      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50       9.8G      1.769      1.065   0.002001        164        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.737       0.61      0.673       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      4.76G      1.777      1.076    0.00199        103        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.5s0.2s
#                    all        548      28033      0.734      0.611      0.672      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      9.35G       1.77      1.064   0.001963        216        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:22<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.3it/s 3.4s0.2s
#                    all        548      28033      0.734      0.612      0.674      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       7.4G      1.771      1.066   0.001972        130        960: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:21<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s0.2s
#                    all        548      28033      0.737      0.612      0.673       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      8.86G      1.768      1.066    0.00196        257        960: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:21<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s0.2s
#                    all        548      28033      0.737      0.613      0.673      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50       5.7G      1.765      1.058   0.001944        151        960: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s0.2s
#                    all        548      28033      0.737      0.614      0.675      0.392
#
# 50 epochs completed in 2.181 hours.
# Optimizer stripped from /kaggle/working/ultralytics/runs/detect/run-6/weights/last.pt, 5.4MB
# Optimizer stripped from /kaggle/working/ultralytics/runs/detect/run-6/weights/best.pt, 5.4MB
#
# Validating /kaggle/working/ultralytics/runs/detect/run-6/weights/best.pt...
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.3it/s 5.5s0.1s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        548      28033      0.738      0.614      0.676      0.392
#                 person        531      13969      0.678      0.483      0.553      0.236
#                    car        515      14064      0.798      0.744      0.798      0.549
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/ultralytics/runs/detect/run-6
# 💡 Learn more at https://docs.ultralytics.com/modes/train
